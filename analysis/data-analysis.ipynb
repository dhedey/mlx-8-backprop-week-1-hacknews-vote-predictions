# %% [markdown]
# # HackerNews Score Distribution Analysis
#
# This notebook analyzes the distribution of HackerNews post scores using data from `summary-scores.csv`.

# %% [markdown]
# ## Import Required Libraries
#
# Import pandas for data manipulation and matplotlib.pyplot for visualization.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
import scipy.stats as stats

# %% [markdown]
# ## Load the Dataset
#
# Use pandas to load 'summary-scores.csv' into a DataFrame and inspect the first few rows.

# %%
# Load the summary-scores.csv file
df = pd.read_csv('./summary-scores.csv')

# Display basic information about the dataset
print("Dataset shape:", df.shape)
print("\nFirst 10 rows:")
print(df.head(10))

print("\nDataset info:")
print(df.info())

print("\nBasic statistics:")
print(df.describe())
# Out:
# Dataset shape: (1860, 2)
#
# First 10 rows:
#    score    count
# 0      1  1267462
# 1      2   959621
# 2      3   447302
# 3      4   208190
# 4      5   113948
# 5      6    73267
# 6      7    52891
# 7      8    40376
# 8      9    32419
# 9     10    26726
#
# Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1860 entries, 0 to 1859
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   score   1860 non-null   int64
#  1   count   1860 non-null   int64
# dtypes: int64(2)
# memory usage: 29.2 KB
# None
#
# Basic statistics:
#              score         count
# count  1860.000000  1.860000e+03
# mean   1037.908065  2.050622e+03
# std     760.488659  3.874736e+04
# min       1.000000  1.000000e+00
# 25%     465.750000  2.000000e+00
# 50%     930.500000  7.500000e+00
# 75%    1430.250000  7.000000e+01
# max    6015.000000  1.267462e+06

# %% [markdown]
# ## Visualize Data with a Histogram
#
# Use Matplotlib to create a histogram of the scores column from the loaded dataset.

# %%
# Create a histogram of scores weighted by count
# Since we have aggregated data (score, count), we need to expand or weight the histogram

df["log_score"] = [math.log10(x) for x in df["score"]]

axes_normal = df.plot(
    x="score",
    xlabel="Scores",
    y="count",
    ylabel="Frequency",
    kind="scatter",
    legend=False,
    title="Distribution of HackerNews Scores",
)

axes_log = df.plot(
    x="log_score",
    xlabel="Log Scores",
    y="count",
    ylabel="Frequency",
    kind="scatter",
    legend=False,
    title="Distribution of HackerNews Log Scores",
)

# NUM_SAMPLES = 10000
# skip = len(df) / NUM_SAMPLES;
# samples = []
# before_log_score = log
# for x in range(NUM_SAMPLES):
#
#
# # Create the histogram of log scores
# fit_alpha, fit_loc, fit_beta=stats.gamma.fit(log_scores)
# gamma = stats.gamma.rvs(fit_alpha, loc=fit_loc, scale=fit_beta)
# xs = range(gamma.len())
#
# plt.scatter(xs, gamma, color='skyblue', edgecolor='black')
